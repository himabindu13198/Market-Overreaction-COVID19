# %%
from dateutil.parser import parse 
import matplotlib as mpl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
df = pd.read_csv('Time_Series.csv')
df.head()
# Out:
#      Year  Month_Arr
# 0  Jan-11   103137.0
# 1  Feb-11    63619.0
# 2  Mar-11    56951.0
# 3  Apr-11    63664.0
# 4  May-11    88889.0

# %%
def plot_df(df, x, y, title="Monthly Arrivals of Chinese Nationals in the US 2011-2019", xlabel='Year', ylabel='Monthly Arrivals', dpi=100):
    plt.figure(figsize=(20,12), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(x, rotation='vertical')
    plt.show()

plot_df(df, x=df['Year'], y=df['Month_Arr'], title='Monthly Arrivals of Chinese Nationals in the US 2011-2019')

# %% [markdown]
# Dickey_Fuller Test

# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
series = read_csv('Time_Series.csv', header=0, index_col=0, squeeze=True)
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.486858
# p-value: 0.118705
# Critical Values:
# 	1%: -3.504
# 	5%: -2.894
# 	10%: -2.584

# %% [markdown]
# KPSS Test

# %%
from statsmodels.tsa.stattools import kpss
X = series.values
result = kpss(X, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# KPSS Statistic: 0.770019
# p-value: 0.010000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# /Users/annamontserratguerrero/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:1685: FutureWarning: The behavior of using lags=None will change in the next release. Currently lags=None is the same as lags='legacy', and so a sample-size lag length is used. After the next release, the default will change to be the same as lags='auto' which uses an automatic lag length selection method. To silence this warning, either use 'auto' or 'legacy'
#   warn(msg, FutureWarning)
# /Users/annamontserratguerrero/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:1708: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = read_csv('Time_Series.csv', header=0, index_col=0)
plot_acf(series)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
series = read_csv('Time_Series.csv', header=0, index_col=0)
plot_pacf(series, lags=50)
pyplot.show()
# Out:
# /Users/annamontserratguerrero/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
df1 = pd.read_csv('K.csv')
df1.head()
# Out:
#      Year  Month_Arr
# 0  Jan-11   125025.0
# 1  Feb-11    83156.0
# 2  Mar-11    74906.0
# 3  Apr-11    74273.0
# 4  May-11   100492.0

# %%
def plot_df(df1, x, y, title="Monthly Arrivals of South Korean Nationals in the US 2011-2019", xlabel='Year', ylabel='Monthly Arrivals', dpi=100):
    plt.figure(figsize=(20,12), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(x, rotation='vertical')
    plt.show()

plot_df(df1, x=df1['Year'], y=df1['Month_Arr'], title='Monthly Arrivals of South Korean Nationals in the US 2011-2019')

# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
series = read_csv('K.csv', header=0, index_col=0, squeeze=True)
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.989648
# p-value: 0.757021
# Critical Values:
# 	1%: -3.504
# 	5%: -2.894
# 	10%: -2.584

# %%
X = series.values
result = kpss(X, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# KPSS Statistic: 0.825079
# p-value: 0.010000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# /Users/annamontserratguerrero/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:1708: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = read_csv('K.csv', header=0, index_col=0)
plot_acf(series)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
series = read_csv('K.csv', header=0, index_col=0)
plot_pacf(series, lags=50)
pyplot.show()

# %%
df2 = pd.read_csv('Ind.csv')
df2.head()
# Out:
#      Year  Month_Arr
# 0  Jan-11    53317.0
# 1  Feb-11    35594.0
# 2  Mar-11    44787.0
# 3  Apr-11    62136.0
# 4  May-11    90646.0

# %%
def plot_df(df2, x, y, title="Monthly Arrivals of Indian Nationals in the US 2011-2019", xlabel='Year', ylabel='Monthly Arrivals', dpi=100):
    plt.figure(figsize=(20,12), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(x, rotation='vertical')
    plt.show()

plot_df(df2, x=df2['Year'], y=df2['Month_Arr'], title='Monthly Arrivals of Indian Nationals in the US 2011-2019')

# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
series = read_csv('Ind.csv', header=0, index_col=0, squeeze=True)
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.961723
# p-value: 0.766968
# Critical Values:
# 	1%: -3.503
# 	5%: -2.893
# 	10%: -2.584

# %%
X = series.values
result = kpss(X, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# KPSS Statistic: 0.841514
# p-value: 0.010000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# /Users/annamontserratguerrero/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:1708: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = read_csv('Ind.csv', header=0, index_col=0)
plot_acf(series)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
series = read_csv('Ind.csv', header=0, index_col=0)
plot_pacf(series, lags=50)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(15,10), 'figure.dpi':120})

# Import data
df = pd.read_csv('Time_Series.csv', names=['Year'], header=0)

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df['Year']); axes[0, 0].set_title('Original Series')
plot_acf(df['Year'], ax=axes[0, 1])

x = df['Year']
# 1st Differencing
axes[1, 0].plot(x.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(x.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(x.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(x.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# Partial Autocorrelation

# %%
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(x.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(x.diff().dropna(), ax=axes[1])

plt.show()

# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

# Import data
df = pd.read_csv('Time_Series.csv')

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(x.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(x.diff().dropna(), ax=axes[1])

plt.show()
